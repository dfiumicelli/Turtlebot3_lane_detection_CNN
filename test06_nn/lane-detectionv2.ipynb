# %%
# %%writefile train.py
# train_MOLANE.py - Training U-Net su MoLane

import os
import warnings
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torch.amp import autocast, GradScaler
import segmentation_models_pytorch as smp
from tqdm import tqdm
import numpy as np

warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', message='.*UnsupportedFieldAttributeWarning.*')

from dataset import LaneSegmentationDataset
from augmentation import (
    get_training_augmentation_improved,
    get_validation_augmentation_improved,
)
from metrics import LaneMetrics

# ==================== LOSS FUNCTIONS ====================

class FocalTverskyLoss(nn.Module):
    def __init__(self, alpha=0.3, beta=0.7, gamma=0.75, smooth=1.0):
        super().__init__()
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.smooth = smooth
    
    def forward(self, predictions, targets):
        probs = torch.sigmoid(predictions)
        TP = (probs * targets).sum()
        FP = (probs * (1 - targets)).sum()
        FN = ((1 - probs) * targets).sum()
        
        tversky_index = (TP + self.smooth) / (
            TP + self.alpha * FP + self.beta * FN + self.smooth
        )
        
        focal_tversky = torch.pow(1 - tversky_index, self.gamma)
        return focal_tversky


class CombinedLossOptimized(nn.Module):
    def __init__(self, focal_weight=0.6, dice_weight=0.4):
        super().__init__()
        self.focal_weight = focal_weight
        self.dice_weight = dice_weight
        self.focal_tversky = FocalTverskyLoss(alpha=0.3, beta=0.7, gamma=0.75)
    
    def forward(self, predictions, targets):
        focal = self.focal_tversky(predictions, targets)
        
        probs = torch.sigmoid(predictions)
        intersection = (probs * targets).sum()
        dice = (2.0 * intersection + 1.0) / (probs.sum() + targets.sum() + 1.0)
        dice_loss = 1 - dice
        
        return self.focal_weight * focal + self.dice_weight * dice_loss


class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, max_epochs, min_lr=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.max_epochs = max_epochs
        self.min_lr = min_lr
        self.base_lr = optimizer.defaults['lr']
    
    def step(self, epoch):
        if epoch < self.warmup_epochs:
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            lr = self.min_lr + (self.base_lr - self.min_lr) * \
                 0.5 * (1 + np.cos(np.pi * (epoch - self.warmup_epochs) / (self.max_epochs - self.warmup_epochs)))
        
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        
        return lr


# ==================== CONFIGURAZIONE MOLANE ====================

class Config:
    # 🎯 MOLANE PATHS
    MOLANE_BASE = '/kaggle/input/carlane-benchmark/CARLANE/MoLane/data'
    
    # Validation set
    VAL_IMAGES_DIR = os.path.join(MOLANE_BASE, 'val', 'target')
    VAL_MASKS_DIR = '/kaggle/working/molane_val_masks'
    
    # Test set
    TEST_IMAGES_DIR = os.path.join(MOLANE_BASE, 'test', 'target')
    TEST_MASKS_DIR = '/kaggle/working/molane_test_masks'
    
    # Parametri training
    TRAIN_RATIO = 0.8
    VAL_RATIO = 0.2
    
    ENCODER = 'efficientnet-b4'
    ENCODER_WEIGHTS = 'imagenet'
    CLASSES = 1
    ACTIVATION = None
    
    DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
    EPOCHS = 30
    BATCH_SIZE = 16
    LEARNING_RATE = 5e-4
    WEIGHT_DECAY = 1e-4
    DROPOUT = 0.2
    NUM_WORKERS = 4
    
    USE_AMP = True
    WARMUP_EPOCHS = 3
    
    MODEL_DIR = '/kaggle/working/models'
    BEST_MODEL_PATH = os.path.join(MODEL_DIR, 'best_unet_molane.pth')
    LAST_MODEL_PATH = os.path.join(MODEL_DIR, 'last_unet_molane.pth')


# ==================== DATASET WRAPPERS ====================

class TrainAugmentedDataset:
    def __init__(self, dataset, transform):
        self.dataset = dataset
        self.transform = transform
    
    def __len__(self):
        return len(self.dataset)
    
    def __getitem__(self, idx):
        image, mask = self.dataset[idx]
        if self.transform:
            sample = self.transform(image=image, mask=mask)
            image = sample['image']
            mask = sample['mask']
        return image, mask


class ValAugmentedDataset:
    def __init__(self, dataset, transform):
        self.dataset = dataset
        self.transform = transform
    
    def __len__(self):
        return len(self.dataset)
    
    def __getitem__(self, idx):
        image, mask = self.dataset[idx]
        if self.transform:
            sample = self.transform(image=image, mask=mask)
            image = sample['image']
            mask = sample['mask']
        return image, mask


# ==================== TRAINING FUNCTIONS ====================

def create_model(config):
    """Crea il modello U-Net"""
    return smp.Unet(
        encoder_name=config.ENCODER,
        encoder_weights=config.ENCODER_WEIGHTS,
        classes=config.CLASSES,
        activation=config.ACTIVATION,
        decoder_dropout=config.DROPOUT,
    )


def create_dataloaders_molane(config):
    """Crea train/val dataloaders da MoLane"""
    
    print("📂 Caricamento dataset MoLane (val + test)...")
    
    # Carica val + test
    val_dataset = LaneSegmentationDataset(
        images_dir=config.VAL_IMAGES_DIR,
        masks_dir=config.VAL_MASKS_DIR,
        transform=None,
        preprocessing=None,
    )
    
    test_dataset = LaneSegmentationDataset(
        images_dir=config.TEST_IMAGES_DIR,
        masks_dir=config.TEST_MASKS_DIR,
        transform=None,
        preprocessing=None,
    )
    
    full_dataset = ConcatDataset([val_dataset, test_dataset])
    
    total_size = len(full_dataset)
    print(f"✅ Dataset MoLane caricato: {total_size} immagini totali")
    
    train_size = int(config.TRAIN_RATIO * total_size)
    val_size = total_size - train_size
    
    print(f"\n📊 Split ratio: {config.TRAIN_RATIO*100:.1f}% training / {config.VAL_RATIO*100:.1f}% validation")
    print(f"   Train samples: {train_size}")
    print(f"   Val samples: {val_size}")
    
    train_dataset, val_dataset = random_split(
        full_dataset,
        [train_size, val_size],
        generator=torch.Generator().manual_seed(42)
    )
    
    train_dataset_augmented = TrainAugmentedDataset(
        dataset=train_dataset,
        transform=get_training_augmentation_improved(),
    )
    
    val_dataset_augmented = ValAugmentedDataset(
        dataset=val_dataset,
        transform=get_validation_augmentation_improved(),
    )
    
    train_loader = DataLoader(
        train_dataset_augmented,
        batch_size=config.BATCH_SIZE,
        shuffle=True,
        num_workers=config.NUM_WORKERS,
        pin_memory=True,
        prefetch_factor=2,
    )
    
    val_loader = DataLoader(
        val_dataset_augmented,
        batch_size=config.BATCH_SIZE,
        shuffle=False,
        num_workers=config.NUM_WORKERS,
        pin_memory=True,
        prefetch_factor=2,
    )
    
    print(f"✅ DataLoaders creati!")
    return train_loader, val_loader


def train_epoch(model, train_loader, optimizer, loss_fn, device, scaler=None, use_amp=False):
    model.train()
    total_loss = 0
    
    pbar = tqdm(train_loader, desc="Training")
    
    for images, masks in pbar:
        images = images.to(device)
        masks = masks.unsqueeze(1).to(device)
        
        if use_amp and scaler:
            with autocast('cuda'):
                outputs = model(images)
                loss = loss_fn(outputs, masks)
            
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
            scaler.step(optimizer)
            scaler.update()
        else:
            outputs = model(images)
            loss = loss_fn(outputs, masks)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
            optimizer.step()
        
        optimizer.zero_grad()
        total_loss += loss.item()
        pbar.set_postfix({'loss': f'{loss.item():.6f}'})
    
    return total_loss / len(train_loader)


def validate_epoch(model, val_loader, loss_fn, device, threshold=0.5):
    model.eval()
    total_loss = 0
    all_metrics = {'iou': [], 'dice': [], 'f1': []}
    
    with torch.no_grad():
        for images, masks in tqdm(val_loader, desc="Validating"):
            images = images.to(device)
            masks = masks.unsqueeze(1).to(device)
            
            outputs = model(images)
            loss = loss_fn(outputs, masks)
            total_loss += loss.item()
            
            preds = (torch.sigmoid(outputs) > threshold).float()
            
            # ✅ CORRETTO: Calcola le metriche direttamente
            for i in range(preds.shape[0]):
                pred_single = preds[i].squeeze()
                mask_single = masks[i].squeeze()
                
                # Usa le funzioni statiche di LaneMetrics
                all_metrics['iou'].append(LaneMetrics.iou(pred_single, mask_single))
                all_metrics['dice'].append(LaneMetrics.dice_coefficient(pred_single, mask_single))
                all_metrics['f1'].append(LaneMetrics.f1_score(pred_single, mask_single))
    
    avg_loss = total_loss / len(val_loader)
    
    # Calcola le medie
    metrics_result = {
        'iou': np.mean(all_metrics['iou']) if all_metrics['iou'] else 0.0,
        'dice': np.mean(all_metrics['dice']) if all_metrics['dice'] else 0.0,
        'f1': np.mean(all_metrics['f1']) if all_metrics['f1'] else 0.0,
    }
    
    return avg_loss, metrics_result


# ==================== MAIN ====================

def main():
    config = Config()
    
    # Verifica paths
    if not os.path.exists(config.VAL_IMAGES_DIR):
        raise FileNotFoundError(f"❌ Cartella non trovata: {config.VAL_IMAGES_DIR}")
    
    if not os.path.exists(config.VAL_MASKS_DIR):
        raise FileNotFoundError(f"❌ Maschere non trovate: {config.VAL_MASKS_DIR}")
    
    if not os.path.exists(config.TEST_IMAGES_DIR):
        raise FileNotFoundError(f"❌ Cartella non trovata: {config.TEST_IMAGES_DIR}")
    
    if not os.path.exists(config.TEST_MASKS_DIR):
        raise FileNotFoundError(f"❌ Maschere non trovate: {config.TEST_MASKS_DIR}")
    
    os.makedirs(config.MODEL_DIR, exist_ok=True)
    
    print("="*80)
    print("🚀 TRAINING U-NET SU MOLANE")
    print("🎯 Dataset: MoLane val/target + test/target")
    print("🎯 Loss: Focal Tversky (gamma=0.75) + Dice")
    print("⚡ Mixed Precision: Enabled")
    print("="*80)
    print(f"Encoder: {config.ENCODER}")
    print(f"Device: {config.DEVICE}")
    print(f"Learning rate: {config.LEARNING_RATE} (with warmup)")
    print(f"Epochs: {config.EPOCHS}")
    print(f"Batch size: {config.BATCH_SIZE}")
    print("="*80)
    
    model = create_model(config)
    model.to(config.DEVICE)
    
    train_loader, val_loader = create_dataloaders_molane(config)
    
    loss_fn = CombinedLossOptimized(focal_weight=0.6, dice_weight=0.4)
    
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=config.LEARNING_RATE,
        weight_decay=config.WEIGHT_DECAY
    )
    
    scheduler = WarmupCosineScheduler(
        optimizer,
        warmup_epochs=config.WARMUP_EPOCHS,
        max_epochs=config.EPOCHS,
        min_lr=1e-6
    )
    
    scaler = GradScaler() if config.USE_AMP else None
    
    best_iou = 0.0
    best_metrics = {}
    no_improve_count = 0
    patience = 10
    best_threshold = 0.5
    
    print("\n🏋️ Inizio training su MoLane...\n")
    
    for epoch in range(config.EPOCHS):
        print(f"\n{'='*80}")
        print(f"Epoch {epoch + 1}/{config.EPOCHS}")
        print(f"{'='*80}")
        
        current_lr = scheduler.step(epoch)
        
        train_loss = train_epoch(
            model, train_loader, optimizer, loss_fn,
            config.DEVICE, scaler, config.USE_AMP
        )
        
        val_loss, metrics = validate_epoch(
            model, val_loader, loss_fn, config.DEVICE, threshold=best_threshold
        )
        
        print(f"\n📈 RISULTATI VALIDAZIONE:")
        print(f" Train Loss: {train_loss:.4f}")
        print(f" Val Loss: {val_loss:.4f}")
        print(f" ───────────────────────")
        print(f" 🎯 IoU: {metrics['iou']:.4f}")
        print(f" F1: {metrics['f1']:.4f}")
        print(f" Dice: {metrics['dice']:.4f}")
        print(f" LR: {current_lr:.6f}")
        
        torch.save(model.state_dict(), config.LAST_MODEL_PATH)
        
        if metrics['iou'] > best_iou:
            best_iou = metrics['iou']
            best_metrics = metrics
            no_improve_count = 0
            torch.save(model.state_dict(), config.BEST_MODEL_PATH)
            print(f"\n ✅ NUOVO MIGLIOR MODELLO!")
            print(f" IoU: {best_iou:.4f}")
        else:
            no_improve_count += 1
            if no_improve_count >= patience:
                print(f"\n⚠️ Early stopping: nessun miglioramento per {patience} epoch")
                break
    
    print("\n" + "="*80)
    print("✅ TRAINING SU MOLANE COMPLETATO!")
    print("="*80)
    print(f"IoU: {best_iou:.4f} 🎯")
    print(f"F1: {best_metrics['f1']:.4f}")
    print(f"Modello: {config.BEST_MODEL_PATH}")
    print("="*80)


if __name__ == '__main__':
    main()
# Out:
# Overwriting train.py

# %%
# %%writefile dataset.py
# dataset_MOLANE.py - Carica MoLane test/target + val/target

import os
import cv2
import numpy as np
from torch.utils.data import Dataset

class LaneSegmentationDataset(Dataset):
    """
    Dataset per MoLane che carica:
    - Validation set: /kaggle/input/carlane-benchmark/CARLANE/MoLane/data/val/target
    - Test set: /kaggle/input/carlane-benchmark/CARLANE/MoLane/data/test/target
    
    Con le maschere appena create:
    - /kaggle/working/molane_val_masks
    - /kaggle/working/molane_test_masks
    """
    
    def __init__(self, images_dir, masks_dir, transform=None, preprocessing=None):
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.transform = transform
        self.preprocessing = preprocessing
        self.img_size = (512, 512)
        
        # Carica RICORSIVAMENTE tutte le immagini dalle sottocartelle
        self.images_fps = []
        self.masks_fps = []
        
        for root, dirs, files in os.walk(images_dir):
            for file in sorted(files):
                if file.endswith(('.jpg', '.png', '.jpeg')):
                    img_path = os.path.join(root, file)
                    
                    # Mantieni il percorso relativo per trovare la maschera corrispondente
                    rel_path = os.path.relpath(img_path, images_dir)
                    
                    # Maschera corrisponde: stessa struttura, estensione .png
                    mask_rel_path = rel_path.replace('image', 'label').replace('.jpg', '.png')
                    mask_path = os.path.join(masks_dir, mask_rel_path)
                    
                    if os.path.exists(mask_path):
                        self.images_fps.append(img_path)
                        self.masks_fps.append(mask_path)
        
        print(f"✅ Dataset MoLane caricato: {len(self.images_fps)} immagini con maschere")
        
        assert len(self.images_fps) == len(self.masks_fps), \
            f"Numero immagini ({len(self.images_fps)}) != numero maschere ({len(self.masks_fps)})"
    
    def __len__(self):
        return len(self.images_fps)
    
    def __getitem__(self, idx):
        image = cv2.imread(self.images_fps[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        mask = cv2.imread(self.masks_fps[idx], cv2.IMREAD_GRAYSCALE)
        
        # ✅ RIDIMENSIONA PRIMA!
        image = cv2.resize(image, self.img_size, interpolation=cv2.INTER_LINEAR)
        mask = cv2.resize(mask, self.img_size, interpolation=cv2.INTER_NEAREST)
        
        mask = (mask > 127).astype(np.float32)
        
        # ✅ ORA le dimensioni sono uguali!
        if self.transform:
            sample = self.transform(image=image, mask=mask)
        
        return image, mask
# Out:
# Overwriting dataset.py

# %%
# %%writefile augmentation.py
# augmentation_DEFINITIVA.py - BASATA DIRETTAMENTE SULLA DOCUMENTAZIONE UFFICIALE
# Tutti i parametri estratti e verificati dalla documentazione ufficiale di Albumentations
# Nessun parametro inventato o non verificato

import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2


def get_training_augmentation_improved():
    """
    ✅ VERSIONE DEFINITIVA - PARAMETRI DALLA DOCUMENTAZIONE UFFICIALE
    Data augmentation per lane detection
    """

    train_transform = [
        # Resize base
        A.Resize(512, 512),

        # RandomResizedCrop - parametri corretti
        A.RandomResizedCrop(
            size=(512, 512),
            scale=(0.8, 1.0),
            ratio=(0.9, 1.1),
            interpolation=cv2.INTER_LINEAR,
            p=0.5
        ),

        # Flip orizzontale
        A.HorizontalFlip(p=0.5),

        # ShiftScaleRotate - parametri verificati
        A.ShiftScaleRotate(
            shift_limit=0.1,
            scale_limit=0.15,
            rotate_limit=15,
            interpolation=cv2.INTER_LINEAR,
            border_mode=cv2.BORDER_CONSTANT,
            fill=0,
            fill_mask=0,
            p=0.7
        ),

        # Perspective - parametri dalla documentazione ufficiale
        # scale: distortion scale (0.05, 0.1)
        # keep_size: resize back to original (True)
        # fit_output: adjust plane size (False)
        # border_mode: padding mode (cv2.BORDER_CONSTANT)
        # fill: padding value (0)
        # fill_mask: padding for mask (0)
        A.Perspective(
            scale=(0.05, 0.1),
            keep_size=True,
            fit_output=False,
            border_mode=cv2.BORDER_CONSTANT,
            fill=0,
            fill_mask=0,
            interpolation=cv2.INTER_LINEAR,
            p=0.3
        ),

        # RandomBrightnessContrast - parametri verificati
        A.RandomBrightnessContrast(
            brightness_limit=0.3,
            contrast_limit=0.3,
            p=0.5
        ),

        # CLAHE - parametri verificati
        A.CLAHE(
            clip_limit=2.0,
            tile_grid_size=(8, 8),
            p=0.4
        ),

        # GaussianBlur - parametri verificati
        A.GaussianBlur(
            blur_limit=(3, 5),
            p=0.2
        ),

        # CoarseDropout - parametri dalla documentazione ufficiale
        # num_holes_range: tuple (min, max) number of holes
        # hole_height_range: tuple (min, max) height range
        # hole_width_range: tuple (min, max) width range
        # fill: fill value ('random_uniform' per colore casuale)
        # fill_mask: mask fill value (None per non cambiare mask)
        A.CoarseDropout(
            num_holes_range=(1, 8),
            hole_height_range=(8, 32),
            hole_width_range=(8, 32),
            fill="random_uniform",
            fill_mask=0,
            p=0.3
        ),

        # RandomRain - parametri dalla documentazione ufficiale
        # slant_range: tuple (min, max) for slant angle
        # drop_length: int or None - length of drops (None = auto)
        # drop_width: int - width of drops
        # drop_color: tuple RGB
        # blur_value: int - blur amount
        # brightness_coefficient: float (0, 1] - brightness multiplier
        # rain_type: "drizzle", "heavy", "torrential", or "default"
        A.RandomRain(
            slant_range=(-10, 10),
            drop_length=20,
            drop_width=1,
            drop_color=(200, 200, 200),
            blur_value=3,
            brightness_coefficient=0.8,
            rain_type="drizzle",
            p=0.1
        ),

        # RandomFog - parametri dalla documentazione ufficiale
        # alpha_coef: float (0, 1] - transparency of fog
        # fog_coef_range: tuple (min, max) for fog intensity
        A.RandomFog(
            alpha_coef=0.08,
            fog_coef_range=(0.3, 1),
            p=0.1
        ),

        # Normalizzazione ImageNet
        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),

        # Conversione a PyTorch format
        ToTensorV2(),
    ]

    return A.Compose(train_transform)


def get_validation_augmentation_improved():
    """
    Augmentation per validation - solo resize + normalize
    """

    val_transform = [
        A.Resize(512, 512),

        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),

        ToTensorV2(),
    ]

    return A.Compose(val_transform)


def get_moderate_augmentation():
    """
    ✅ AUGMENTATION MODERATA
    Versione più leggera se quella aggressiva causa problemi
    """

    train_transform = [
        A.Resize(512, 512),

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(
            shift_limit=0.0625,
            scale_limit=0.1,
            rotate_limit=10,
            border_mode=cv2.BORDER_CONSTANT,
            fill=0,
            fill_mask=0,
            p=0.6
        ),

        A.RandomBrightnessContrast(
            brightness_limit=0.2,
            contrast_limit=0.2,
            p=0.5
        ),

        A.CLAHE(
            clip_limit=2.0,
            tile_grid_size=(8, 8),
            p=0.3
        ),

        A.GaussianBlur(blur_limit=3, p=0.2),

        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),

        ToTensorV2(),
    ]

    return A.Compose(train_transform)


def get_light_augmentation():
    """
    ✅ AUGMENTATION LEGGERA
    Solo trasformazioni essenziali
    """

    train_transform = [
        A.Resize(512, 512),

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(
            shift_limit=0.05,
            scale_limit=0.1,
            rotate_limit=10,
            border_mode=cv2.BORDER_CONSTANT,
            fill=0,
            fill_mask=0,
            p=0.5
        ),

        A.RandomBrightnessContrast(
            brightness_limit=0.2,
            contrast_limit=0.2,
            p=0.5
        ),

        A.CLAHE(
            clip_limit=2.0,
            tile_grid_size=(8, 8),
            p=0.3
        ),

        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),

        ToTensorV2(),
    ]

    return A.Compose(train_transform)


def get_test_time_augmentation():
    """
    ✅ Test Time Augmentation (TTA)
    Solo flip orizzontale - il più sicuro e efficace
    """

    tta_transforms = []

    # Original
    tta_transforms.append(A.Compose([
        A.Resize(512, 512),
        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),
        ToTensorV2(),
    ]))

    # Horizontal flip
    tta_transforms.append(A.Compose([
        A.Resize(512, 512),
        A.HorizontalFlip(p=1.0),
        A.Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
            max_pixel_value=255.0,
        ),
        ToTensorV2(),
    ]))

    return tta_transforms


# ==================== TESTING ====================
if __name__ == '__main__':
    import numpy as np

    print("✅ Test augmentation definitiva (parametri ufficiali)...\n")

    # Immagine e mask dummy
    dummy_image = np.random.randint(0, 255, (720, 1280, 3), dtype=np.uint8)
    dummy_mask = np.random.randint(0, 2, (720, 1280), dtype=np.float32)

    try:
        # Test training augmentation
        print("📊 Testing Training Augmentation (Full)...")
        train_aug = get_training_augmentation_improved()
        augmented = train_aug(image=dummy_image, mask=dummy_mask)

        print(f"   Input shape: {dummy_image.shape}")
        print(f"   Output image shape: {augmented['image'].shape}")
        print(f"   Output mask shape: {augmented['mask'].shape}")
        print(f"   Image dtype: {augmented['image'].dtype}")
        print(f"   Mask dtype: {augmented['mask'].dtype}")
        print(f"   ✅ Training augmentation OK!")

        # Test validation augmentation
        print("\n📊 Testing Validation Augmentation...")
        val_aug = get_validation_augmentation_improved()
        val_augmented = val_aug(image=dummy_image, mask=dummy_mask)
        print(f"   Output image shape: {val_augmented['image'].shape}")
        print(f"   Output mask shape: {val_augmented['mask'].shape}")
        print(f"   ✅ Validation augmentation OK!")

        # Test moderate augmentation
        print("\n📊 Testing Moderate Augmentation...")
        mod_aug = get_moderate_augmentation()
        mod_augmented = mod_aug(image=dummy_image, mask=dummy_mask)
        print(f"   ✅ Moderate augmentation OK!")

        # Test light augmentation
        print("\n📊 Testing Light Augmentation...")
        light_aug = get_light_augmentation()
        light_augmented = light_aug(image=dummy_image, mask=dummy_mask)
        print(f"   ✅ Light augmentation OK!")

        # Test TTA
        print("\n📊 Testing TTA...")
        tta_transforms = get_test_time_augmentation()
        print(f"   TTA transforms: {len(tta_transforms)}")
        print(f"   ✅ TTA OK!")

        print("\n" + "=" * 70)
        print("✅ TUTTI I TEST COMPLETATI CON SUCCESSO!")
        print("=" * 70)
        print("\n📝 COME USARE:")
        print("1. Per training: get_training_augmentation_improved()")
        print("2. Se overfitting: get_moderate_augmentation()")
        print("3. Se dataset piccolo: get_light_augmentation()")
        print("4. Per validation: get_validation_augmentation_improved()")
        print("5. Per TTA inference: get_test_time_augmentation()")
        print("\n✅ File pronto per essere usato in train.py!")

    except Exception as e:
        print(f"\n❌ ERRORE: {e}")
        import traceback

        traceback.print_exc()
        print("\nVerifica che albumentations sia aggiornato:")
        print("pip install -U albumentations")
# Out:
# Writing augmentation.py

# %%
# %%writefile metrics.py
# metrics_CORRECTED.py - METRICHE CORRETTE PER LANE DETECTION

import torch
import numpy as np

class LaneMetrics:
    """Metriche specializzate per lane detection - VERSIONE CORRETTA"""
    
    # ==================== 1️⃣ DICE COEFFICIENT ====================
    @staticmethod
    def dice_coefficient(pred, target, smooth=1.0):
        """
        ✅ CORRETTO
        Formula: Dice = (2 * TP) / (2 * TP + FP + FN)
        """
        # Converti a binario (pred potrebbe già essere binario o probabilità)
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        intersection = (pred_binary * target).sum()
        dice = (2.0 * intersection + smooth) / (pred_binary.sum() + target.sum() + smooth)
        return dice.item()
    
    
    # ==================== 2️⃣ SENSITIVITY (RECALL) ====================
    @staticmethod
    def sensitivity(pred, target, smooth=1e-6):
        """
        ✅ CORRETTO
        Formula: Sensitivity = TP / (TP + FN)
        
        ⚠️ BUG ORIGINALE: Non convertiva pred a binario!
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        TP = (pred_binary * target).sum()
        FN = ((1 - pred_binary) * target).sum()
        
        sensitivity = TP / (TP + FN + smooth)
        return sensitivity.item()
    
    
    # ==================== 3️⃣ SPECIFICITY ====================
    @staticmethod
    def specificity(pred, target, smooth=1e-6):
        """
        ✅ CORRETTO
        Formula: Specificity = TN / (TN + FP)
        
        ⚠️ BUG ORIGINALE: Non convertiva pred a binario!
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        TN = ((1 - pred_binary) * (1 - target)).sum()
        FP = (pred_binary * (1 - target)).sum()
        
        specificity = TN / (TN + FP + smooth)
        return specificity.item()
    
    
    # ==================== 4️⃣ F1 SCORE ====================
    @staticmethod
    def f1_score(pred, target, smooth=1e-6):
        """
        ✅ CORRETTO
        Formula: F1 = 2 * (Precision * Recall) / (Precision + Recall)
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        TP = (pred_binary * target).sum()
        FP = (pred_binary * (1 - target)).sum()
        FN = ((1 - pred_binary) * target).sum()
        
        precision = TP / (TP + FP + smooth)
        recall = TP / (TP + FN + smooth)
        f1 = 2 * (precision * recall) / (precision + recall + smooth)
        
        return f1.item()
    
    
    # ==================== 5️⃣ MATTHEWS CORRELATION COEFFICIENT ====================
    @staticmethod
    def mcc(pred, target, smooth=1e-6):
        """
        ✅ CORRETTO
        Formula: MCC = (TP*TN - FP*FN) / sqrt((TP+FP)(TP+FN)(TN+FP)(TN+FN))
        
        ⚠️ BUG ORIGINALE: Non gestiva correttamente i tensori
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        TP = (pred_binary * target).sum()
        TN = ((1 - pred_binary) * (1 - target)).sum()
        FP = (pred_binary * (1 - target)).sum()
        FN = ((1 - pred_binary) * target).sum()
        
        numerator = TP * TN - FP * FN
        denominator = torch.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN) + smooth)
        
        # ✅ FIX: Gestisci il caso di denominatore zero
        if denominator == 0:
            return 0.0
        
        mcc = numerator / denominator
        return mcc.item()
    
    
    # ==================== 6️⃣ PIXEL ACCURACY ====================
    @staticmethod
    def pixel_accuracy(pred, target, smooth=1e-6):
        """
        ✅ CORRETTO
        Formula: Accuracy = (TP + TN) / Total
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        correct = (pred_binary == target).float().sum()
        total = target.numel()
        
        # ✅ FIX: Gestisci il caso di total zero
        if total == 0:
            return 0.0
        
        return (correct / total).item()
    
    
    # ==================== 7️⃣ IoU (Intersection over Union) ====================
    @staticmethod
    def iou(pred, target, smooth=1e-6):
        """
        ✅ AGGIUNTO - Lo standard per segmentazione
        Formula: IoU = TP / (TP + FP + FN)
        """
        # ✅ FIX: Converti a binario
        if pred.max() > 1.0:
            pred_binary = (pred > 0.5).float()
        else:
            pred_binary = pred
        
        target = target.float()
        
        intersection = (pred_binary * target).sum()
        union = pred_binary.sum() + target.sum() - intersection
        
        iou_score = (intersection + smooth) / (union + smooth)
        return iou_score.item()


# ==================== FUNZIONE DI UTILITÀ ====================

def calculate_all_metrics(pred_batch, target_batch):
    """
    ✅ CORRETTA - Calcola tutte le metriche per un batch
    
    Input:
        pred_batch: tensor [B, H, W] con probabilità [0, 1] o valori > 1
        target_batch: tensor [B, H, W] con valori binari {0, 1}
    
    Output:
        dict con tutte le metriche
    """
    metrics = {
        'iou': [],
        'dice': [],
        'sensitivity': [],
        'specificity': [],
        'f1': [],
        'mcc': [],
        'accuracy': [],
    }
    
    # ✅ FIX: Itera correttamente su ogni elemento del batch
    for batch_idx in range(pred_batch.shape[0]):
        pred_single = pred_batch[batch_idx]    # [H, W]
        target_single = target_batch[batch_idx] # [H, W]
        
        # Calcola tutte le metriche per questa immagine
        metrics['iou'].append(LaneMetrics.iou(pred_single, target_single))
        metrics['dice'].append(LaneMetrics.dice_coefficient(pred_single, target_single))
        metrics['sensitivity'].append(LaneMetrics.sensitivity(pred_single, target_single))
        metrics['specificity'].append(LaneMetrics.specificity(pred_single, target_single))
        metrics['f1'].append(LaneMetrics.f1_score(pred_single, target_single))
        metrics['mcc'].append(LaneMetrics.mcc(pred_single, target_single))
        metrics['accuracy'].append(LaneMetrics.pixel_accuracy(pred_single, target_single))
    
    # ✅ Restituisci media di tutte le metriche
    return {k: np.mean(v) if v else 0.0 for k, v in metrics.items()}


# ==================== DEBUG ====================

if __name__ == '__main__':
    print("✅ Test metriche corrette...\n")
    
    # Crea dati fittizi
    pred = torch.rand(256, 256)           # Probabilità [0, 1]
    target = torch.randint(0, 2, (256, 256)).float()  # Binario
    
    print("📊 Metriche per Lane Detection:\n")
    print(f"  IoU:              {LaneMetrics.iou(pred, target):.4f}")
    print(f"  Dice:             {LaneMetrics.dice_coefficient(pred, target):.4f}")
    print(f"  Sensitivity:      {LaneMetrics.sensitivity(pred, target):.4f} ← Corsie trovate")
    print(f"  Specificity:      {LaneMetrics.specificity(pred, target):.4f} ← Falsi positivi")
    print(f"  F1 Score:         {LaneMetrics.f1_score(pred, target):.4f}")
    print(f"  MCC:              {LaneMetrics.mcc(pred, target):.4f}")
    print(f"  Accuracy:         {LaneMetrics.pixel_accuracy(pred, target):.4f}")
    
    # Test batch
    print("\n\n📊 Test Batch:\n")
    pred_batch = torch.rand(4, 256, 256)
    target_batch = torch.randint(0, 2, (4, 256, 256)).float()
    
    all_metrics = calculate_all_metrics(pred_batch, target_batch)
    for k, v in all_metrics.items():
        print(f"  {k.upper():12s}: {v:.4f}")
# Out:
# Writing metrics.py

# %%
# !pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.0rc2)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.19)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (0.28.1)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (0.19.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.1.10)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.3->segmentation_models_pytorch) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->segmentation_models_pytorch) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (8.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (1.3.1)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.3 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 4.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ================================================================================
# 🚀 TRAINING U-NET SU MOLANE
# 🎯 Dataset: MoLane val/target + test/target
# 🎯 Loss: Focal Tversky (gamma=0.75) + Dice
# ⚡ Mixed Precision: Enabled
# ================================================================================
# Encoder: efficientnet-b4
# Device: cuda
# Learning rate: 0.0005 (with warmup)
# Epochs: 30
# Batch size: 16
# ================================================================================
# 📂 Caricamento dataset MoLane (val + test)...
# ✅ Dataset MoLane caricato: 4000 immagini con maschere
# ✅ Dataset MoLane caricato: 2000 immagini con maschere
# ✅ Dataset MoLane caricato: 6000 immagini totali
#
# 📊 Split ratio: 80.0% training / 20.0% validation
#    Train samples: 4800
#    Val samples: 1200
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# ✅ DataLoaders creati!
#
# 🏋️ Inizio training su MoLane...
#
#
# ================================================================================
# Epoch 1/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:15<00:00,  1.18it/s, loss=0.460569]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.92it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.6934
#  Val Loss: 0.2918
#  ───────────────────────
#  🎯 IoU: 0.7548
#  F1: 0.8395
#  Dice: 0.8395
#  LR: 0.000167
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.7548
#
# ================================================================================
# Epoch 2/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.238531]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.91it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.3828
#  Val Loss: 0.1868
#  ───────────────────────
#  🎯 IoU: 0.7828
#  F1: 0.8671
#  Dice: 0.8672
#  LR: 0.000333
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.7828
#
# ================================================================================
# Epoch 3/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.364296]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.94it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.3425
#  Val Loss: 0.1765
#  ───────────────────────
#  🎯 IoU: 0.7517
#  F1: 0.8445
#  Dice: 0.8445
#  LR: 0.000500
#
# ================================================================================
# Epoch 4/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.19it/s, loss=0.211994]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.3211
#  Val Loss: 0.1605
#  ───────────────────────
#  🎯 IoU: 0.7776
#  F1: 0.8641
#  Dice: 0.8641
#  LR: 0.000500
#
# ================================================================================
# Epoch 5/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.437155]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.3144
#  Val Loss: 0.1684
#  ───────────────────────
#  🎯 IoU: 0.7692
#  F1: 0.8606
#  Dice: 0.8606
#  LR: 0.000498
#
# ================================================================================
# Epoch 6/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.182248]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.96it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2994
#  Val Loss: 0.1219
#  ───────────────────────
#  🎯 IoU: 0.8418
#  F1: 0.9045
#  Dice: 0.9045
#  LR: 0.000493
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8418
#
# ================================================================================
# Epoch 7/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.206506]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2995
#  Val Loss: 0.1508
#  ───────────────────────
#  🎯 IoU: 0.7845
#  F1: 0.8724
#  Dice: 0.8724
#  LR: 0.000485
#
# ================================================================================
# Epoch 8/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.273147]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2917
#  Val Loss: 0.1224
#  ───────────────────────
#  🎯 IoU: 0.8425
#  F1: 0.9029
#  Dice: 0.9029
#  LR: 0.000473
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8425
#
# ================================================================================
# Epoch 9/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.241162]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.3017
#  Val Loss: 0.1260
#  ───────────────────────
#  🎯 IoU: 0.8278
#  F1: 0.8963
#  Dice: 0.8963
#  LR: 0.000459
#
# ================================================================================
# Epoch 10/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.143646]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2905
#  Val Loss: 0.1397
#  ───────────────────────
#  🎯 IoU: 0.8179
#  F1: 0.8913
#  Dice: 0.8914
#  LR: 0.000442
#
# ================================================================================
# Epoch 11/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.264971]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2894
#  Val Loss: 0.1224
#  ───────────────────────
#  🎯 IoU: 0.8385
#  F1: 0.9046
#  Dice: 0.9046
#  LR: 0.000422
#
# ================================================================================
# Epoch 12/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.142807]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2760
#  Val Loss: 0.1505
#  ───────────────────────
#  🎯 IoU: 0.7954
#  F1: 0.8680
#  Dice: 0.8680
#  LR: 0.000399
#
# ================================================================================
# Epoch 13/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.327677]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2858
#  Val Loss: 0.1302
#  ───────────────────────
#  🎯 IoU: 0.8095
#  F1: 0.8808
#  Dice: 0.8809
#  LR: 0.000375
#
# ================================================================================
# Epoch 14/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.19it/s, loss=0.241035]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2767
#  Val Loss: 0.1552
#  ───────────────────────
#  🎯 IoU: 0.8139
#  F1: 0.8720
#  Dice: 0.8720
#  LR: 0.000349
#
# ================================================================================
# Epoch 15/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.221368]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2751
#  Val Loss: 0.1093
#  ───────────────────────
#  🎯 IoU: 0.8664
#  F1: 0.9202
#  Dice: 0.9202
#  LR: 0.000322
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8664
#
# ================================================================================
# Epoch 16/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.304717]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2780
#  Val Loss: 0.1071
#  ───────────────────────
#  🎯 IoU: 0.8614
#  F1: 0.9173
#  Dice: 0.9174
#  LR: 0.000294
#
# ================================================================================
# Epoch 17/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.276711]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2734
#  Val Loss: 0.1257
#  ───────────────────────
#  🎯 IoU: 0.8220
#  F1: 0.8956
#  Dice: 0.8956
#  LR: 0.000265
#
# ================================================================================
# Epoch 18/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.218375]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2671
#  Val Loss: 0.1063
#  ───────────────────────
#  🎯 IoU: 0.8625
#  F1: 0.9195
#  Dice: 0.9196
#  LR: 0.000236
#
# ================================================================================
# Epoch 19/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.364842]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.93it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2643
#  Val Loss: 0.1038
#  ───────────────────────
#  🎯 IoU: 0.8625
#  F1: 0.9187
#  Dice: 0.9187
#  LR: 0.000207
#
# ================================================================================
# Epoch 20/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.347647]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.94it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2608
#  Val Loss: 0.1030
#  ───────────────────────
#  🎯 IoU: 0.8599
#  F1: 0.9172
#  Dice: 0.9172
#  LR: 0.000179
#
# ================================================================================
# Epoch 21/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.254512]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.96it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2559
#  Val Loss: 0.1071
#  ───────────────────────
#  🎯 IoU: 0.8583
#  F1: 0.9162
#  Dice: 0.9162
#  LR: 0.000152
#
# ================================================================================
# Epoch 22/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.242450]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.94it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2641
#  Val Loss: 0.1012
#  ───────────────────────
#  🎯 IoU: 0.8691
#  F1: 0.9226
#  Dice: 0.9226
#  LR: 0.000126
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8691
#
# ================================================================================
# Epoch 23/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.227386]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2507
#  Val Loss: 0.0998
#  ───────────────────────
#  🎯 IoU: 0.8732
#  F1: 0.9246
#  Dice: 0.9246
#  LR: 0.000102
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8732
#
# ================================================================================
# Epoch 24/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.243758]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.94it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2559
#  Val Loss: 0.0992
#  ───────────────────────
#  🎯 IoU: 0.8743
#  F1: 0.9260
#  Dice: 0.9260
#  LR: 0.000079
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8743
#
# ================================================================================
# Epoch 25/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.246666]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.94it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2490
#  Val Loss: 0.0976
#  ───────────────────────
#  🎯 IoU: 0.8772
#  F1: 0.9272
#  Dice: 0.9272
#  LR: 0.000059
#
#  ✅ NUOVO MIGLIOR MODELLO!
#  IoU: 0.8772
#
# ================================================================================
# Epoch 26/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.152177]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2502
#  Val Loss: 0.0979
#  ───────────────────────
#  🎯 IoU: 0.8730
#  F1: 0.9250
#  Dice: 0.9250
#  LR: 0.000042
#
# ================================================================================
# Epoch 27/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.19it/s, loss=0.238823]
# Validating: 100%|███████████████████████████████| 75/75 [00:18<00:00,  3.98it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2487
#  Val Loss: 0.0967
#  ───────────────────────
#  🎯 IoU: 0.8753
#  F1: 0.9261
#  Dice: 0.9261
#  LR: 0.000028
#
# ================================================================================
# Epoch 28/30
# ================================================================================
# Training: 100%|████████████████| 300/300 [04:13<00:00,  1.18it/s, loss=0.311718]
# Validating: 100%|███████████████████████████████| 75/75 [00:19<00:00,  3.95it/s]
#
# 📈 RISULTATI VALIDAZIONE:
#  Train Loss: 0.2466
#  Val Loss: 0.0963
#  ───────────────────────
#  🎯 IoU: 0.8743
#  F1: 0.9259
#  Dice: 0.9259
#  LR: 0.000016
#
# ================================================================================
# Epoch 29/30
# ================================================================================
# Training:  67%|██████████▊     | 202/300 [02:51<01:22,  1.19it/s, loss=0.181161]

# %%
# %%writefile adaptation.py
# ============================================
# FINE-TUNING CON MOLANE LABELS - VERSIONE CORRETTA
# ============================================

import torch
import torch.nn as nn
import torch.optim as optim
import os
import cv2
import numpy as np
from torch.utils.data import DataLoader, Dataset, ConcatDataset
import segmentation_models_pytorch as smp
from tqdm import tqdm
import gc

# ============================================
# LOSS FUNCTIONS
# ============================================

class FocalTverskyLoss(nn.Module):
    def __init__(self, alpha=0.3, beta=0.7, gamma=0.75, smooth=1.0):
        super().__init__()
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.smooth = smooth
    
    def forward(self, predictions, targets):
        probs = torch.sigmoid(predictions)
        TP = (probs * targets).sum()
        FP = (probs * (1 - targets)).sum()
        FN = ((1 - probs) * targets).sum()
        
        tversky_index = (TP + self.smooth) / (
            TP + self.alpha * FP + self.beta * FN + self.smooth
        )
        
        focal_tversky = torch.pow(1 - tversky_index, self.gamma)
        return focal_tversky


class CombinedLossOptimized(nn.Module):
    def __init__(self, focal_weight=0.6, dice_weight=0.4):
        super().__init__()
        self.focal_weight = focal_weight
        self.dice_weight = dice_weight
        self.focal_tversky = FocalTverskyLoss(alpha=0.3, beta=0.7, gamma=0.75)
    
    def forward(self, predictions, targets):
        focal = self.focal_tversky(predictions, targets)
        
        probs = torch.sigmoid(predictions)
        intersection = (probs * targets).sum()
        dice = (2.0 * intersection + 1.0) / (probs.sum() + targets.sum() + 1.0)
        dice_loss = 1 - dice
        
        return self.focal_weight * focal + self.dice_weight * dice_loss


# ============================================
# UTILITIES
# ============================================

def cleanup_memory():
    gc.collect()
    torch.cuda.empty_cache()


# ============================================
# DATASET
# ============================================

class MoLaneLabeledDataset(Dataset):
    def __init__(self, images_base_dir, masks_base_dir, img_size=(512, 512)):
        self.img_size = img_size
        self.images_base_dir = images_base_dir
        self.masks_base_dir = masks_base_dir
        self.image_files = []
        
        print(f"🔍 Searching for labeled samples...")
        
        for root, dirs, files in os.walk(images_base_dir):
            for file in files:
                if file.endswith(('.jpg', '.png')):
                    rel_path = os.path.relpath(os.path.join(root, file), images_base_dir)
                    self.image_files.append(rel_path)
        
        self.image_files = sorted(self.image_files)
        print(f"✅ Found {len(self.image_files)} labeled samples\n")
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        img_rel_path = self.image_files[idx]
        
        img_path = os.path.join(self.images_base_dir, img_rel_path)
        img = cv2.imread(img_path)
        
        if img is None:
            return self.__getitem__(0)
        
        # 🔧 CORREZIONE: Sostituisci "image" con "label" E ".jpg" con ".png"
        mask_rel_path = img_rel_path.replace('image', 'label').replace('.jpg', '.png')
        mask_path = os.path.join(self.masks_base_dir, mask_rel_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        if mask is None:
            print(f"⚠️ Could not load mask: {mask_path}")
            return self.__getitem__(0)
        
        img = cv2.resize(img, self.img_size)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img.astype(np.float32) / 255.0
        img = np.transpose(img, (2, 0, 1))
        
        mask = cv2.resize(mask, self.img_size, interpolation=cv2.INTER_NEAREST)
        mask = mask.astype(np.float32) / 255.0
        
        return torch.from_numpy(img).float(), torch.from_numpy(mask).float()



# ============================================
# TRAINING
# ============================================

def train_epoch(model, train_loader, loss_fn, optimizer, device, epoch, total_epochs):
    model.train()
    total_loss = 0
    
    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{total_epochs}")
    
    for images, masks in pbar:
        images = images.to(device)
        masks = masks.unsqueeze(1).to(device)
        
        outputs = model(images)
        loss = loss_fn(outputs, masks)
        
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
        optimizer.step()
        
        total_loss += loss.item()
        pbar.set_postfix({'loss': f'{loss.item():.6f}'})  # ← CORRETTO!
    
    avg_loss = total_loss / len(train_loader)
    return avg_loss


def validate(model, val_loader, loss_fn, device):
    model.eval()
    total_loss = 0
    
    with torch.no_grad():
        for images, masks in tqdm(val_loader, desc="Validating"):
            images = images.to(device)
            masks = masks.unsqueeze(1).to(device)
            
            outputs = model(images)
            loss = loss_fn(outputs, masks)
            total_loss += loss.item()
    
    avg_loss = total_loss / len(val_loader)
    return avg_loss


# ============================================
# MAIN
# ============================================

def main():
    print("\n" + "="*80)
    print("🚀 FINE-TUNING ON MOLANE LABELED DATA")
    print("="*80 + "\n")
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}\n")
    
    cleanup_memory()
    
    # ============ STEP 1: Carica Dataset ============
    print("STEP 1: Loading labeled datasets...")
    print("-" * 60)
    
    val_images = '/kaggle/input/carlane-benchmark/CARLANE/MoLane/data/val/target'
    val_masks = '/kaggle/working/molane_val_masks'
    
    try:
        val_dataset = MoLaneLabeledDataset(val_images, val_masks)
        val_loader = DataLoader(val_dataset, batch_size=10, shuffle=False, num_workers=1)
    except Exception as e:
        print(f"❌ Error loading validation set: {e}")
        return
    
    test_images = '/kaggle/input/carlane-benchmark/CARLANE/MoLane/data/test/target'
    test_masks = '/kaggle/working/molane_test_masks'
    
    try:
        test_dataset = MoLaneLabeledDataset(test_images, test_masks)
        test_loader = DataLoader(test_dataset, batch_size=10, shuffle=False, num_workers=1)
    except Exception as e:
        print(f"❌ Error loading test set: {e}")
        test_dataset = None
    
    if test_dataset:
        combined_dataset = ConcatDataset([val_dataset, test_dataset])
        print(f"✅ Validation set: {len(val_dataset)} samples")
        print(f"✅ Test set: {len(test_dataset)} samples")
    else:
        combined_dataset = val_dataset
        print(f"✅ Validation set: {len(val_dataset)} samples")
    
    train_loader = DataLoader(combined_dataset, batch_size=10, shuffle=True, num_workers=1)
    print(f"✅ Combined: {len(combined_dataset)} samples\n")
    
    # ============ STEP 2: Carica Modello ============
    print("STEP 2: Loading pre-trained model...")
    print("-" * 60)
    
    print("📂 Loading model...")
    
    model = smp.Unet(
        encoder_name='efficientnet-b4',
        encoder_weights='imagenet',
        classes=1,
        activation=None,
        decoder_dropout=0.2,
    )
    
    model_path = '/kaggle/input/best-unet/pytorch/default/1/best_unet_improved.pth'
    checkpoint = torch.load(model_path, map_location=device)
    
    if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
        model.load_state_dict(checkpoint['model_state_dict'])
    else:
        model.load_state_dict(checkpoint)
    
    model = model.to(device)
    print("✅ Model loaded\n")
    
    # ============ STEP 3: Setup Training ============
    print("STEP 3: Setting up training...")
    print("-" * 60)
    
    loss_fn = CombinedLossOptimized(focal_weight=0.6, dice_weight=0.4)
    optimizer = optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
    
    print(f"Loss: Focal Tversky (0.6) + Dice (0.4)")
    print(f"Optimizer: AdamW (lr=1e-5)")
    print(f"Scheduler: CosineAnnealing\n")
    
    # ============ STEP 4: Training Loop ============
    print("STEP 4: Training...")
    print("-" * 60 + "\n")
    
    num_epochs = 10
    best_loss = float('inf')
    patience = 3
    patience_counter = 0
    
    for epoch in range(num_epochs):
        train_loss = train_epoch(model, train_loader, loss_fn, optimizer, 
                                device, epoch, num_epochs)
        val_loss = validate(model, val_loader, loss_fn, device)
        
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.6f}")
        print(f"  Val Loss: {val_loss:.6f}")
        
        scheduler.step()
        
        if val_loss < best_loss:
            best_loss = val_loss
            patience_counter = 0
            print(f"  ✅ Best validation loss!")
        else:
            patience_counter += 1
            print(f"  ⚠️ No improvement ({patience_counter}/{patience})")
        
        if patience_counter >= patience:
            print(f"\n⛔ Early stopping after {epoch+1} epochs")
            break
        
        print()
    
    # ============ STEP 5: Salva Modello ============
    print("STEP 5: Saving model...")
    print("-" * 60)
    
    output_dir = '/kaggle/working'
    os.makedirs(output_dir, exist_ok=True)
    
    weights_path = os.path.join(output_dir, 'unet_finetuned_molane_weights.pth')
    torch.save(model.state_dict(), weights_path)
    
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'adaptation_method': 'Fine-tuning on MoLane labeled data',
        'loss_function': 'Focal Tversky (0.6) + Dice (0.4)',
        'timestamp': str(__import__('datetime').datetime.now())
    }
    
    checkpoint_path = os.path.join(output_dir, 'unet_finetuned_molane_checkpoint.pth')
    torch.save(checkpoint, checkpoint_path)
    
    print(f"✅ Weights saved to: {weights_path}")
    print(f"✅ Checkpoint saved to: {checkpoint_path}\n")
    
    # ============ FINALE ============
    print("="*60)
    print("✨ FINE-TUNING COMPLETED!")
    print("="*60)
    print(f"\n📊 Summary:")
    print(f"   • Training samples: {len(combined_dataset)}")
    print(f"   • Best validation loss: {best_loss:.6f}")
    print(f"   • Total epochs: {epoch+1}")
    print(f"   • Model: smp.Unet(efficientnet-b4)")
    print(f"   • Loss: Focal Tversky + Dice")
    print(f"\n🎉 Model ready for deployment on your robot!")


if __name__ == "__main__":
    main()
# Out:
# Overwriting adaptation.py

# %%
# !python adaptation.py
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
#
# ================================================================================
# 🚀 FINE-TUNING ON MOLANE LABELED DATA
# ================================================================================
#
# Device: cuda
#
# STEP 1: Loading labeled datasets...
# ------------------------------------------------------------
# 🔍 Searching for labeled samples...
# ✅ Found 4000 labeled samples
#
# 🔍 Searching for labeled samples...
# ✅ Found 2000 labeled samples
#
# ✅ Validation set: 4000 samples
# ✅ Test set: 2000 samples
# ✅ Combined: 6000 samples
#
# STEP 2: Loading pre-trained model...
# ------------------------------------------------------------
# 📂 Loading model...
# ✅ Model loaded
#
# STEP 3: Setting up training...
# ------------------------------------------------------------
# Loss: Focal Tversky (0.6) + Dice (0.4)
# Optimizer: AdamW (lr=1e-5)
# Scheduler: CosineAnnealing
#
# STEP 4: Training...
# ------------------------------------------------------------
#
# Epoch 1/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.271387]
# Validating: 100%|█████████████████████████████| 400/400 [01:17<00:00,  5.17it/s]
#
# Epoch 1/10
#   Train Loss: 0.347454
#   Val Loss: 0.253355
#   ✅ Best validation loss!
#
# Epoch 2/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.194849]
# Validating: 100%|█████████████████████████████| 400/400 [01:16<00:00,  5.23it/s]
#
# Epoch 2/10
#   Train Loss: 0.243881
#   Val Loss: 0.226688
#   ✅ Best validation loss!
#
# Epoch 3/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.240010]
# Validating: 100%|█████████████████████████████| 400/400 [01:15<00:00,  5.32it/s]
#
# Epoch 3/10
#   Train Loss: 0.224891
#   Val Loss: 0.215545
#   ✅ Best validation loss!
#
# Epoch 4/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.232302]
# Validating: 100%|█████████████████████████████| 400/400 [01:16<00:00,  5.26it/s]
#
# Epoch 4/10
#   Train Loss: 0.216098
#   Val Loss: 0.209200
#   ✅ Best validation loss!
#
# Epoch 5/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.177826]
# Validating: 100%|█████████████████████████████| 400/400 [01:16<00:00,  5.20it/s]
#
# Epoch 5/10
#   Train Loss: 0.210603
#   Val Loss: 0.205925
#   ✅ Best validation loss!
#
# Epoch 6/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.186789]
# Validating: 100%|█████████████████████████████| 400/400 [01:14<00:00,  5.35it/s]
#
# Epoch 6/10
#   Train Loss: 0.207518
#   Val Loss: 0.203649
#   ✅ Best validation loss!
#
# Epoch 7/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.200960]
# Validating: 100%|█████████████████████████████| 400/400 [01:16<00:00,  5.25it/s]
#
# Epoch 7/10
#   Train Loss: 0.205499
#   Val Loss: 0.202129
#   ✅ Best validation loss!
#
# Epoch 8/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.203111]
# Validating: 100%|█████████████████████████████| 400/400 [01:15<00:00,  5.33it/s]
#
# Epoch 8/10
#   Train Loss: 0.204512
#   Val Loss: 0.201205
#   ✅ Best validation loss!
#
# Epoch 9/10: 100%|██████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.182733]
# Validating: 100%|█████████████████████████████| 400/400 [01:15<00:00,  5.33it/s]
#
# Epoch 9/10
#   Train Loss: 0.203480
#   Val Loss: 0.200894
#   ✅ Best validation loss!
#
# Epoch 10/10: 100%|█████████████| 600/600 [05:57<00:00,  1.68it/s, loss=0.242118]
# Validating: 100%|█████████████████████████████| 400/400 [01:15<00:00,  5.32it/s]
#
# Epoch 10/10
#   Train Loss: 0.203177
#   Val Loss: 0.200806
#   ✅ Best validation loss!
#
# STEP 5: Saving model...
# ------------------------------------------------------------
# ✅ Weights saved to: /kaggle/working/unet_finetuned_molane_weights.pth
# ✅ Checkpoint saved to: /kaggle/working/unet_finetuned_molane_checkpoint.pth
#
# ============================================================
# ✨ FINE-TUNING COMPLETED!
# ============================================================
#
# 📊 Summary:
#    • Training samples: 6000
#    • Best validation loss: 0.200806
#    • Total epochs: 10
#    • Model: smp.Unet(efficientnet-b4)
#    • Loss: Focal Tversky + Dice
#
# 🎉 Model ready for deployment on your robot!

# %%
# %%writefile conv.py
# ============================================
# SOLUTION: Copy existing labels directly
# ============================================

import os
import cv2
import shutil
from pathlib import Path

print("\n" + "="*80)
print("📋 COPYING EXISTING LABELS DIRECTLY")
print("="*80 + "\n")

molane_base = '/kaggle/input/carlane-benchmark/CARLANE/MoLane'
data_dir = os.path.join(molane_base, 'data')

# ============ VAL SET ============
print("🔷 VALIDATION SET")
print("="*80)

val_source = os.path.join(data_dir, 'val', 'target')
val_output = '/kaggle/working/molane_val_masks'

os.makedirs(val_output, exist_ok=True)

# Copia TUTTI i file .png da val/target (mantenendo struttura)
val_count = 0
for root, dirs, files in os.walk(val_source):
    for file in files:
        if file.endswith('.png'):
            # Mantieni la struttura delle subdirectory
            rel_path = os.path.relpath(os.path.join(root, file), val_source)
            output_subdir = os.path.dirname(os.path.join(val_output, rel_path))
            os.makedirs(output_subdir, exist_ok=True)
            
            src_path = os.path.join(root, file)
            dst_path = os.path.join(val_output, rel_path)
            
            # Ridimensiona mentre copi
            img = cv2.imread(src_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img_resized = cv2.resize(img, (512, 512), interpolation=cv2.INTER_NEAREST)
                cv2.imwrite(dst_path, img_resized)
                val_count += 1

print(f"✅ Copied {val_count} validation masks")

# ============ TEST SET ============
print("\n🔶 TEST SET")
print("="*80)

test_source = os.path.join(data_dir, 'test', 'target')
test_output = '/kaggle/working/molane_test_masks'

os.makedirs(test_output, exist_ok=True)

# Copia TUTTI i file .png da test/target
test_count = 0
for root, dirs, files in os.walk(test_source):
    for file in files:
        if file.endswith('.png'):
            rel_path = os.path.relpath(os.path.join(root, file), test_source)
            output_subdir = os.path.dirname(os.path.join(test_output, rel_path))
            os.makedirs(output_subdir, exist_ok=True)
            
            src_path = os.path.join(root, file)
            dst_path = os.path.join(test_output, rel_path)
            
            # Ridimensiona mentre copi
            img = cv2.imread(src_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img_resized = cv2.resize(img, (512, 512), interpolation=cv2.INTER_NEAREST)
                cv2.imwrite(dst_path, img_resized)
                test_count += 1

print(f"✅ Copied {test_count} test masks")

# ============ VERIFICA ============
print("\n" + "="*80)
print("✨ FINAL RESULTS")
print("="*80)
print(f"\n✅ Validation masks: {val_count}")
print(f"✅ Test masks: {test_count}")
print(f"✅ Total: {val_count + test_count}")

print(f"\n📁 Output locations:")
print(f"   • /kaggle/working/molane_val_masks ({val_count} files)")
print(f"   • /kaggle/working/molane_test_masks ({test_count} files)")

print(f"\n🎉 Ready for fine-tuning!\n")

# Verifica che i file siano stati salvati
if val_count > 0 and test_count > 0:
    print("✓ SUCCESS! Masks are ready to use")
else:
    print("❌ FAILED! Check the output directories")
# Out:
# Overwriting conv.py

# %%
# %%writefile rescale_conv.py
# ============================================
# FIX: Riscala i valori delle maschere a 0-255
# ============================================

import os
import cv2
import numpy as np
from tqdm import tqdm

print("\n" + "="*80)
print("🔧 FIXING MASK VALUES")
print("="*80 + "\n")

def fix_mask_values(mask_dir):
    """Riscala i valori delle maschere da [0,2] a [0,255]"""
    
    fixed_count = 0
    
    for root, dirs, files in os.walk(mask_dir):
        for file in tqdm(files):
            if file.endswith('.png'):
                mask_path = os.path.join(root, file)
                
                # Leggi la maschera
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                
                if mask is None:
                    continue
                
                # Riscala i valori
                # Se max è 2, moltiplica per 127.5 per portare a 0-255
                if mask.max() > 0:
                    mask_fixed = np.uint8((mask / mask.max()) * 255)
                else:
                    mask_fixed = mask.astype(np.uint8)
                
                # Salva la maschera corretta
                cv2.imwrite(mask_path, mask_fixed)
                fixed_count += 1
    
    return fixed_count

# ============ FIX VALIDATION ============
print("🔷 Fixing validation masks...")
val_masks = '/kaggle/working/molane_val_masks'
val_fixed = fix_mask_values(val_masks)
print(f"✅ Fixed {val_fixed} validation masks\n")

# ============ FIX TEST ============
print("🔶 Fixing test masks...")
test_masks = '/kaggle/working/molane_test_masks'
test_fixed = fix_mask_values(test_masks)
print(f"✅ Fixed {test_fixed} test masks\n")

# ============ VERIFICA ============
print("="*80)
print("🔍 VERIFICATION")
print("="*80 + "\n")

# Verifica il primo file di ogni set
for label, mask_dir in [("Validation", val_masks), ("Test", test_masks)]:
    for root, dirs, files in os.walk(mask_dir):
        for file in files:
            if file.endswith('.png'):
                test_path = os.path.join(root, file)
                mask = cv2.imread(test_path, cv2.IMREAD_GRAYSCALE)
                
                print(f"{label} sample: {os.path.relpath(test_path, mask_dir)}")
                print(f"  Shape: {mask.shape}")
                print(f"  Min: {mask.min()}")
                print(f"  Max: {mask.max()}")
                print(f"  Mean: {mask.mean():.2f}")
                print(f"  Lane pixels (255): {(mask == 255).sum()}")
                print(f"  Background pixels (0): {(mask == 0).sum()}\n")
                break
        else:
            continue
        break

print("="*80)
print("✨ MASKS FIXED AND READY!")
print("="*80 + "\n")
# Out:
# Writing rescale_conv.py

# %%
import cv2
import numpy as np

# Leggi una maschera
mask = cv2.imread('/kaggle/working/molane_val_masks/roundtrack/black/left_curve/dark/0001_label.png', 
                   cv2.IMREAD_GRAYSCALE)

print(f"Mask shape: {mask.shape}")
print(f"Min value: {mask.min()}")
print(f"Max value: {mask.max()}")
print(f"Mean value: {mask.mean():.2f}")
print(f"Pixels with lane (255): {(mask == 255).sum()}")
print(f"Pixels without lane (0): {(mask == 0).sum()}")
# Out:
# Mask shape: (512, 512)
# Min value: 0
# Max value: 2
# Mean value: 0.04
# Pixels with lane (255): 0
# Pixels without lane (0): 255315

# %%
# !python conv.py
# Out:
# ================================================================================
# 📋 COPYING EXISTING LABELS DIRECTLY
# ================================================================================
#
# 🔷 VALIDATION SET
# ================================================================================
# ✅ Copied 2000 validation masks
#
# 🔶 TEST SET
# ================================================================================
# ✅ Copied 1000 test masks
#
# ================================================================================
# ✨ FINAL RESULTS
# ================================================================================
#
# ✅ Validation masks: 2000
# ✅ Test masks: 1000
# ✅ Total: 3000
#
# 📁 Output locations:
#    • /kaggle/working/molane_val_masks (2000 files)
#    • /kaggle/working/molane_test_masks (1000 files)
#
# 🎉 Ready for fine-tuning!
#
# ✓ SUCCESS! Masks are ready to use

# %%
# ============================================
# COMPRESS AND DOWNLOAD
# ============================================

import os
import zipfile
import shutil

print("\n" + "="*80)
print("📦 COMPRESSING MASKS FOR DOWNLOAD")
print("="*80 + "\n")

# Crea una cartella ZIP
output_dir = '/kaggle/working'
zip_path = os.path.join(output_dir, 'molane_masks.zip')

print(f"Creating ZIP file: {zip_path}\n")

with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Aggiungi validation masks
    val_dir = os.path.join(output_dir, 'molane_val_masks')
    for root, dirs, files in os.walk(val_dir):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, output_dir)
            zipf.write(file_path, arcname)
            print(f"  ✓ Added {arcname}")
    
    # Aggiungi test masks
    test_dir = os.path.join(output_dir, 'molane_test_masks')
    for root, dirs, files in os.walk(test_dir):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, output_dir)
            zipf.write(file_path, arcname)
            print(f"  ✓ Added {arcname}")

# Verifica il file
zip_size = os.path.getsize(zip_path) / 1e9
print(f"\n✅ ZIP created!")
print(f"   Size: {zip_size:.2f} GB")
print(f"   Path: {zip_path}")

print("\n📥 DOWNLOAD:")
print("   Go to 'Output' tab and download 'molane_masks.zip'")
# Out:
# ================================================================================
# 📦 COMPRESSING MASKS FOR DOWNLOAD
# ================================================================================
#
# Creating ZIP file: /kaggle/working/molane_masks.zip
#
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0123_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0086_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0025_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0014_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0094_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0041_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0001_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0097_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0112_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0067_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0036_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0118_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0100_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0064_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0003_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0049_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0024_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0053_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0096_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0065_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0051_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0028_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0093_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0037_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0089_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0080_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0010_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0101_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0009_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0095_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0057_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0020_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0056_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0011_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0098_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0109_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0038_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0106_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0061_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0120_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0103_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0088_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0030_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0108_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0115_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0007_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0076_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0085_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0021_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0026_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0099_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0002_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0119_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0058_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0047_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0054_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0072_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0043_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0071_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0074_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0107_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0069_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0040_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0027_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0032_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0117_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0090_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0039_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0116_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0121_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0046_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0104_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0016_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0035_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0018_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0063_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0008_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0017_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0062_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0113_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0033_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0006_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0004_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0110_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0092_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0060_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0050_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0012_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0078_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0029_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0048_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0081_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0091_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0045_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0042_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0044_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0083_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0005_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0087_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0082_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0000_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0034_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0102_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0052_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0059_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0122_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0084_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0015_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0105_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0023_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0075_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0111_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0019_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0013_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0077_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0070_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0066_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0022_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0073_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0031_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0055_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0079_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/light/0114_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0123_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0086_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0025_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0014_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0094_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0041_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0001_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0097_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0112_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0067_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0036_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0118_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0100_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0064_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0003_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0049_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0024_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0053_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0096_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0065_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0051_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0028_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0093_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0037_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0089_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0080_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0010_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0101_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0009_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0095_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0057_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0020_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0056_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0011_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0098_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0109_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0038_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0106_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0061_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0120_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0103_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0088_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0030_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0108_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0115_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0007_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0076_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0085_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0021_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0026_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0099_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0002_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0119_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0058_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0047_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0054_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0072_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0043_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0071_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0074_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0107_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0069_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0040_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0027_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0032_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0117_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0090_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0039_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0116_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0121_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0046_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0104_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0016_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0035_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0018_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0063_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0008_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0017_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0062_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0113_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0033_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0006_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0004_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0110_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0092_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0060_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0050_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0012_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0078_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0029_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0048_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0081_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0091_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0045_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0042_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0044_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0083_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0005_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0087_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0082_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0000_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0034_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0102_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0052_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0059_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0122_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0084_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0015_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0105_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0023_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0075_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0111_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0019_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0013_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0077_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0070_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0066_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0022_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0073_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0031_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0055_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0079_label.png
#   ✓ Added molane_val_masks/roundtrack/black/right_curve/dark/0114_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0123_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0086_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0025_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0014_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0094_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0041_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0001_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0097_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0112_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0067_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0036_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0118_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0100_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0064_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0003_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0049_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0024_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0053_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0096_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0065_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0051_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0028_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0093_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0037_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0089_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0080_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0010_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0101_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0009_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0095_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0057_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0020_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0056_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0011_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0098_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0109_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0038_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0106_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0061_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0120_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0103_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0088_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0030_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0108_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0115_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0007_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0076_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0085_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0021_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0026_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0099_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0002_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0119_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0058_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0047_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0054_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0072_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0043_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0071_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0074_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0107_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0069_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0040_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0027_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0032_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0117_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0090_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0039_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0116_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0121_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0046_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0104_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0016_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0035_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0018_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0063_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0008_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0017_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0062_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0113_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0033_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0006_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0004_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0110_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0092_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0060_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0050_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0012_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0078_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0029_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0048_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0081_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0091_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0045_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0042_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0044_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0083_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0005_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0087_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0082_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0000_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0034_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0102_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0052_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0059_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0122_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0084_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0015_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0105_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0023_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0075_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0111_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0019_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0013_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0077_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0070_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0066_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0022_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0073_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0031_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0055_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0079_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/light/0114_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0123_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0086_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0025_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0014_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0094_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0041_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0001_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0097_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0112_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0067_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0036_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0118_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0100_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0064_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0003_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0049_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0024_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0053_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0096_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0065_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0051_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0028_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0093_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0037_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0089_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0080_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0010_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0101_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0009_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0095_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0057_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0020_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0056_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0011_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0098_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0109_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0038_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0106_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0061_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0120_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0103_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0088_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0030_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0108_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0115_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0007_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0076_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0085_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0021_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0026_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0099_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0002_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0119_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0058_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0047_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0054_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0072_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0043_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0071_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0074_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0107_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0069_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0040_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0027_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0032_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0117_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0090_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0039_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0116_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0121_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0046_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0104_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0016_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0035_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0018_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0063_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0008_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0017_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0062_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0113_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0033_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0006_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0004_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0110_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0092_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0060_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0050_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0012_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0078_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0029_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0048_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0081_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0091_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0045_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0042_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0044_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0083_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0005_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0087_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0082_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0000_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0034_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0102_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0052_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0059_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0122_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0084_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0015_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0105_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0023_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0075_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0111_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0019_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0013_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0077_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0070_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0066_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0022_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0073_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0031_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0055_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0079_label.png
#   ✓ Added molane_val_masks/roundtrack/black/left_curve/dark/0114_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0123_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0086_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0025_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0014_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0094_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0041_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0001_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0097_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0112_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0067_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0036_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0118_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0100_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0064_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0003_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0049_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0024_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0053_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0096_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0065_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0051_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0028_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0093_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0037_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0089_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0080_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0010_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0101_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0009_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0095_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0057_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0020_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0056_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0011_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0098_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0109_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0038_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0106_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0061_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0120_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0103_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0088_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0030_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0108_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0115_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0007_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0076_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0085_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0021_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0026_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0099_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0002_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0119_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0058_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0047_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0054_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0072_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0043_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0071_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0074_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0107_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0069_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0040_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0027_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0032_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0117_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0090_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0039_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0116_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0121_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0046_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0104_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0016_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0035_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0018_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0063_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0008_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0017_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0062_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0113_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0033_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0006_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0004_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0110_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0092_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0060_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0050_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0012_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0078_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0029_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0048_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0081_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0091_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0045_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0042_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0044_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0083_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0005_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0087_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0082_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0000_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0034_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0102_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0052_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0059_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0122_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0084_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0015_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0105_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0023_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0075_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0111_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0019_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0013_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0077_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0070_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0066_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0022_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0073_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0031_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0055_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0079_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/light/0114_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/dark/0068_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/dark/0124_label.png
#   ✓ Added molane_val_masks/roundtrack/gray/right_curve/dark/0123_label.png
# ...
#   ✓ Added molane_test_masks/gray/0278_label.png
#   ✓ Added molane_test_masks/gray/0088_label.png
#   ✓ Added molane_test_masks/gray/0160_label.png
#   ✓ Added molane_test_masks/gray/0030_label.png
#   ✓ Added molane_test_masks/gray/0300_label.png
#   ✓ Added molane_test_masks/gray/0242_label.png
#   ✓ Added molane_test_masks/gray/0108_label.png
#   ✓ Added molane_test_masks/gray/0285_label.png
#   ✓ Added molane_test_masks/gray/0267_label.png
#   ✓ Added molane_test_masks/gray/0316_label.png
#   ✓ Added molane_test_masks/gray/0230_label.png
#   ✓ Added molane_test_masks/gray/0115_label.png
#   ✓ Added molane_test_masks/gray/0388_label.png
#   ✓ Added molane_test_masks/gray/0007_label.png
#   ✓ Added molane_test_masks/gray/0394_label.png
#   ✓ Added molane_test_masks/gray/0436_label.png
#   ✓ Added molane_test_masks/gray/0261_label.png
#   ✓ Added molane_test_masks/gray/0076_label.png
#   ✓ Added molane_test_masks/gray/0334_label.png
#   ✓ Added molane_test_masks/gray/0256_label.png
#   ✓ Added molane_test_masks/gray/0355_label.png
#   ✓ Added molane_test_masks/gray/0331_label.png
#   ✓ Added molane_test_masks/gray/0175_label.png
#   ✓ Added molane_test_masks/gray/0459_label.png
#   ✓ Added molane_test_masks/gray/0439_label.png
#   ✓ Added molane_test_masks/gray/0419_label.png
#   ✓ Added molane_test_masks/gray/0234_label.png
#   ✓ Added molane_test_masks/gray/0381_label.png
#   ✓ Added molane_test_masks/gray/0180_label.png
#   ✓ Added molane_test_masks/gray/0383_label.png
#   ✓ Added molane_test_masks/gray/0140_label.png
#   ✓ Added molane_test_masks/gray/0386_label.png
#   ✓ Added molane_test_masks/gray/0416_label.png
#   ✓ Added molane_test_masks/gray/0085_label.png
#   ✓ Added molane_test_masks/gray/0021_label.png
#   ✓ Added molane_test_masks/gray/0026_label.png
#   ✓ Added molane_test_masks/gray/0392_label.png
#   ✓ Added molane_test_masks/gray/0450_label.png
#   ✓ Added molane_test_masks/gray/0336_label.png
#   ✓ Added molane_test_masks/gray/0302_label.png
#   ✓ Added molane_test_masks/gray/0099_label.png
#   ✓ Added molane_test_masks/gray/0415_label.png
#   ✓ Added molane_test_masks/gray/0238_label.png
#   ✓ Added molane_test_masks/gray/0269_label.png
#   ✓ Added molane_test_masks/gray/0244_label.png
#   ✓ Added molane_test_masks/gray/0153_label.png
#   ✓ Added molane_test_masks/gray/0264_label.png
#   ✓ Added molane_test_masks/gray/0437_label.png
#   ✓ Added molane_test_masks/gray/0430_label.png
#   ✓ Added molane_test_masks/gray/0002_label.png
#   ✓ Added molane_test_masks/gray/0271_label.png
#   ✓ Added molane_test_masks/gray/0363_label.png
#   ✓ Added molane_test_masks/gray/0277_label.png
#   ✓ Added molane_test_masks/gray/0332_label.png
#   ✓ Added molane_test_masks/gray/0321_label.png
#   ✓ Added molane_test_masks/gray/0119_label.png
#   ✓ Added molane_test_masks/gray/0289_label.png
#   ✓ Added molane_test_masks/gray/0434_label.png
#   ✓ Added molane_test_masks/gray/0058_label.png
#   ✓ Added molane_test_masks/gray/0047_label.png
#   ✓ Added molane_test_masks/gray/0489_label.png
#   ✓ Added molane_test_masks/gray/0233_label.png
#   ✓ Added molane_test_masks/gray/0135_label.png
#   ✓ Added molane_test_masks/gray/0143_label.png
#   ✓ Added molane_test_masks/gray/0362_label.png
#   ✓ Added molane_test_masks/gray/0199_label.png
#   ✓ Added molane_test_masks/gray/0474_label.png
#   ✓ Added molane_test_masks/gray/0054_label.png
#   ✓ Added molane_test_masks/gray/0231_label.png
#   ✓ Added molane_test_masks/gray/0382_label.png
#   ✓ Added molane_test_masks/gray/0481_label.png
#   ✓ Added molane_test_masks/gray/0158_label.png
#   ✓ Added molane_test_masks/gray/0412_label.png
#   ✓ Added molane_test_masks/gray/0265_label.png
#   ✓ Added molane_test_masks/gray/0072_label.png
#   ✓ Added molane_test_masks/gray/0182_label.png
#   ✓ Added molane_test_masks/gray/0370_label.png
#   ✓ Added molane_test_masks/gray/0445_label.png
#   ✓ Added molane_test_masks/gray/0174_label.png
#   ✓ Added molane_test_masks/gray/0043_label.png
#   ✓ Added molane_test_masks/gray/0407_label.png
#   ✓ Added molane_test_masks/gray/0384_label.png
#   ✓ Added molane_test_masks/gray/0071_label.png
#   ✓ Added molane_test_masks/gray/0074_label.png
#   ✓ Added molane_test_masks/gray/0408_label.png
#   ✓ Added molane_test_masks/gray/0466_label.png
#   ✓ Added molane_test_masks/gray/0129_label.png
#   ✓ Added molane_test_masks/gray/0185_label.png
#   ✓ Added molane_test_masks/gray/0360_label.png
#   ✓ Added molane_test_masks/gray/0107_label.png
#   ✓ Added molane_test_masks/gray/0212_label.png
#   ✓ Added molane_test_masks/gray/0139_label.png
#   ✓ Added molane_test_masks/gray/0201_label.png
#   ✓ Added molane_test_masks/gray/0402_label.png
#   ✓ Added molane_test_masks/gray/0413_label.png
#   ✓ Added molane_test_masks/gray/0069_label.png
#   ✓ Added molane_test_masks/gray/0485_label.png
#   ✓ Added molane_test_masks/gray/0040_label.png
#   ✓ Added molane_test_masks/gray/0282_label.png
#   ✓ Added molane_test_masks/gray/0442_label.png
#   ✓ Added molane_test_masks/gray/0027_label.png
#   ✓ Added molane_test_masks/gray/0157_label.png
#   ✓ Added molane_test_masks/gray/0192_label.png
#   ✓ Added molane_test_masks/gray/0032_label.png
#   ✓ Added molane_test_masks/gray/0132_label.png
#   ✓ Added molane_test_masks/gray/0210_label.png
#   ✓ Added molane_test_masks/gray/0117_label.png
#   ✓ Added molane_test_masks/gray/0490_label.png
#   ✓ Added molane_test_masks/gray/0463_label.png
#   ✓ Added molane_test_masks/gray/0303_label.png
#   ✓ Added molane_test_masks/gray/0090_label.png
#   ✓ Added molane_test_masks/gray/0433_label.png
#   ✓ Added molane_test_masks/gray/0275_label.png
#   ✓ Added molane_test_masks/gray/0039_label.png
#   ✓ Added molane_test_masks/gray/0484_label.png
#   ✓ Added molane_test_masks/gray/0144_label.png
#   ✓ Added molane_test_masks/gray/0196_label.png
#   ✓ Added molane_test_masks/gray/0324_label.png
#   ✓ Added molane_test_masks/gray/0128_label.png
#   ✓ Added molane_test_masks/gray/0358_label.png
#   ✓ Added molane_test_masks/gray/0356_label.png
#   ✓ Added molane_test_masks/gray/0202_label.png
#   ✓ Added molane_test_masks/gray/0149_label.png
#   ✓ Added molane_test_masks/gray/0483_label.png
#   ✓ Added molane_test_masks/gray/0397_label.png
#   ✓ Added molane_test_masks/gray/0253_label.png
#   ✓ Added molane_test_masks/gray/0307_label.png
#   ✓ Added molane_test_masks/gray/0246_label.png
#   ✓ Added molane_test_masks/gray/0137_label.png
#   ✓ Added molane_test_masks/gray/0488_label.png
#   ✓ Added molane_test_masks/gray/0206_label.png
#   ✓ Added molane_test_masks/gray/0154_label.png
#   ✓ Added molane_test_masks/gray/0254_label.png
#   ✓ Added molane_test_masks/gray/0357_label.png
#   ✓ Added molane_test_masks/gray/0130_label.png
#   ✓ Added molane_test_masks/gray/0379_label.png
#   ✓ Added molane_test_masks/gray/0116_label.png
#   ✓ Added molane_test_masks/gray/0492_label.png
#   ✓ Added molane_test_masks/gray/0141_label.png
#   ✓ Added molane_test_masks/gray/0203_label.png
#   ✓ Added molane_test_masks/gray/0367_label.png
#   ✓ Added molane_test_masks/gray/0159_label.png
#   ✓ Added molane_test_masks/gray/0178_label.png
#   ✓ Added molane_test_masks/gray/0121_label.png
#   ✓ Added molane_test_masks/gray/0219_label.png
#   ✓ Added molane_test_masks/gray/0376_label.png
#   ✓ Added molane_test_masks/gray/0046_label.png
#   ✓ Added molane_test_masks/gray/0104_label.png
#   ✓ Added molane_test_masks/gray/0016_label.png
#   ✓ Added molane_test_masks/gray/0365_label.png
#   ✓ Added molane_test_masks/gray/0494_label.png
#   ✓ Added molane_test_masks/gray/0340_label.png
#   ✓ Added molane_test_masks/gray/0035_label.png
#   ✓ Added molane_test_masks/gray/0453_label.png
#   ✓ Added molane_test_masks/gray/0364_label.png
#   ✓ Added molane_test_masks/gray/0018_label.png
#   ✓ Added molane_test_masks/gray/0435_label.png
#   ✓ Added molane_test_masks/gray/0150_label.png
#   ✓ Added molane_test_masks/gray/0405_label.png
#   ✓ Added molane_test_masks/gray/0213_label.png
#   ✓ Added molane_test_masks/gray/0145_label.png
#   ✓ Added molane_test_masks/gray/0440_label.png
#   ✓ Added molane_test_masks/gray/0377_label.png
#   ✓ Added molane_test_masks/gray/0428_label.png
#   ✓ Added molane_test_masks/gray/0449_label.png
#   ✓ Added molane_test_masks/gray/0063_label.png
#   ✓ Added molane_test_masks/gray/0133_label.png
#   ✓ Added molane_test_masks/gray/0344_label.png
#   ✓ Added molane_test_masks/gray/0008_label.png
#   ✓ Added molane_test_masks/gray/0017_label.png
#   ✓ Added molane_test_masks/gray/0062_label.png
#   ✓ Added molane_test_masks/gray/0313_label.png
#   ✓ Added molane_test_masks/gray/0346_label.png
#   ✓ Added molane_test_masks/gray/0404_label.png
#   ✓ Added molane_test_masks/gray/0113_label.png
#   ✓ Added molane_test_masks/gray/0164_label.png
#   ✓ Added molane_test_masks/gray/0033_label.png
#   ✓ Added molane_test_masks/gray/0006_label.png
#   ✓ Added molane_test_masks/gray/0136_label.png
#   ✓ Added molane_test_masks/gray/0004_label.png
#   ✓ Added molane_test_masks/gray/0110_label.png
#   ✓ Added molane_test_masks/gray/0399_label.png
#   ✓ Added molane_test_masks/gray/0092_label.png
#   ✓ Added molane_test_masks/gray/0272_label.png
#   ✓ Added molane_test_masks/gray/0414_label.png
#   ✓ Added molane_test_masks/gray/0127_label.png
#   ✓ Added molane_test_masks/gray/0420_label.png
#   ✓ Added molane_test_masks/gray/0177_label.png
#   ✓ Added molane_test_masks/gray/0391_label.png
#   ✓ Added molane_test_masks/gray/0146_label.png
#   ✓ Added molane_test_masks/gray/0274_label.png
#   ✓ Added molane_test_masks/gray/0060_label.png
#   ✓ Added molane_test_masks/gray/0354_label.png
#   ✓ Added molane_test_masks/gray/0393_label.png
#   ✓ Added molane_test_masks/gray/0451_label.png
#   ✓ Added molane_test_masks/gray/0280_label.png
#   ✓ Added molane_test_masks/gray/0304_label.png
#   ✓ Added molane_test_masks/gray/0200_label.png
#   ✓ Added molane_test_masks/gray/0444_label.png
#   ✓ Added molane_test_masks/gray/0050_label.png
#   ✓ Added molane_test_masks/gray/0314_label.png
#   ✓ Added molane_test_masks/gray/0211_label.png
#   ✓ Added molane_test_masks/gray/0012_label.png
#   ✓ Added molane_test_masks/gray/0315_label.png
#   ✓ Added molane_test_masks/gray/0078_label.png
#   ✓ Added molane_test_masks/gray/0276_label.png
#   ✓ Added molane_test_masks/gray/0341_label.png
#   ✓ Added molane_test_masks/gray/0029_label.png
#   ✓ Added molane_test_masks/gray/0048_label.png
#   ✓ Added molane_test_masks/gray/0478_label.png
#   ✓ Added molane_test_masks/gray/0378_label.png
#   ✓ Added molane_test_masks/gray/0208_label.png
#   ✓ Added molane_test_masks/gray/0320_label.png
#   ✓ Added molane_test_masks/gray/0366_label.png
#   ✓ Added molane_test_masks/gray/0326_label.png
#   ✓ Added molane_test_masks/gray/0372_label.png
#   ✓ Added molane_test_masks/gray/0333_label.png
#   ✓ Added molane_test_masks/gray/0170_label.png
#   ✓ Added molane_test_masks/gray/0258_label.png
#   ✓ Added molane_test_masks/gray/0252_label.png
#   ✓ Added molane_test_masks/gray/0389_label.png
#   ✓ Added molane_test_masks/gray/0186_label.png
#   ✓ Added molane_test_masks/gray/0081_label.png
#   ✓ Added molane_test_masks/gray/0396_label.png
#   ✓ Added molane_test_masks/gray/0470_label.png
#   ✓ Added molane_test_masks/gray/0091_label.png
#   ✓ Added molane_test_masks/gray/0045_label.png
#   ✓ Added molane_test_masks/gray/0426_label.png
#   ✓ Added molane_test_masks/gray/0286_label.png
#   ✓ Added molane_test_masks/gray/0342_label.png
#   ✓ Added molane_test_masks/gray/0042_label.png
#   ✓ Added molane_test_masks/gray/0044_label.png
#   ✓ Added molane_test_masks/gray/0214_label.png
#   ✓ Added molane_test_masks/gray/0083_label.png
#   ✓ Added molane_test_masks/gray/0290_label.png
#   ✓ Added molane_test_masks/gray/0245_label.png
#   ✓ Added molane_test_masks/gray/0189_label.png
#   ✓ Added molane_test_masks/gray/0330_label.png
#   ✓ Added molane_test_masks/gray/0005_label.png
#   ✓ Added molane_test_masks/gray/0087_label.png
#   ✓ Added molane_test_masks/gray/0082_label.png
#   ✓ Added molane_test_masks/gray/0454_label.png
#   ✓ Added molane_test_masks/gray/0000_label.png
#   ✓ Added molane_test_masks/gray/0190_label.png
#   ✓ Added molane_test_masks/gray/0327_label.png
#   ✓ Added molane_test_masks/gray/0469_label.png
#   ✓ Added molane_test_masks/gray/0322_label.png
#   ✓ Added molane_test_masks/gray/0441_label.png
#   ✓ Added molane_test_masks/gray/0281_label.png
#   ✓ Added molane_test_masks/gray/0204_label.png
#   ✓ Added molane_test_masks/gray/0493_label.png
#   ✓ Added molane_test_masks/gray/0297_label.png
#   ✓ Added molane_test_masks/gray/0034_label.png
#   ✓ Added molane_test_masks/gray/0102_label.png
#   ✓ Added molane_test_masks/gray/0317_label.png
#   ✓ Added molane_test_masks/gray/0224_label.png
#   ✓ Added molane_test_masks/gray/0339_label.png
#   ✓ Added molane_test_masks/gray/0325_label.png
#   ✓ Added molane_test_masks/gray/0134_label.png
#   ✓ Added molane_test_masks/gray/0221_label.png
#   ✓ Added molane_test_masks/gray/0262_label.png
#   ✓ Added molane_test_masks/gray/0468_label.png
#   ✓ Added molane_test_masks/gray/0052_label.png
#   ✓ Added molane_test_masks/gray/0387_label.png
#   ✓ Added molane_test_masks/gray/0232_label.png
#   ✓ Added molane_test_masks/gray/0059_label.png
#   ✓ Added molane_test_masks/gray/0425_label.png
#   ✓ Added molane_test_masks/gray/0172_label.png
#   ✓ Added molane_test_masks/gray/0329_label.png
#   ✓ Added molane_test_masks/gray/0122_label.png
#   ✓ Added molane_test_masks/gray/0299_label.png
#   ✓ Added molane_test_masks/gray/0475_label.png
#   ✓ Added molane_test_masks/gray/0171_label.png
#   ✓ Added molane_test_masks/gray/0343_label.png
#   ✓ Added molane_test_masks/gray/0473_label.png
#   ✓ Added molane_test_masks/gray/0084_label.png
#   ✓ Added molane_test_masks/gray/0163_label.png
#   ✓ Added molane_test_masks/gray/0015_label.png
#   ✓ Added molane_test_masks/gray/0499_label.png
#   ✓ Added molane_test_masks/gray/0446_label.png
#   ✓ Added molane_test_masks/gray/0105_label.png
#   ✓ Added molane_test_masks/gray/0217_label.png
#   ✓ Added molane_test_masks/gray/0263_label.png
#   ✓ Added molane_test_masks/gray/0292_label.png
#   ✓ Added molane_test_masks/gray/0223_label.png
#   ✓ Added molane_test_masks/gray/0023_label.png
#   ✓ Added molane_test_masks/gray/0390_label.png
#   ✓ Added molane_test_masks/gray/0075_label.png
#   ✓ Added molane_test_masks/gray/0249_label.png
#   ✓ Added molane_test_masks/gray/0312_label.png
#   ✓ Added molane_test_masks/gray/0296_label.png
#   ✓ Added molane_test_masks/gray/0482_label.png
#   ✓ Added molane_test_masks/gray/0111_label.png
#   ✓ Added molane_test_masks/gray/0019_label.png
#   ✓ Added molane_test_masks/gray/0294_label.png
#   ✓ Added molane_test_masks/gray/0373_label.png
#   ✓ Added molane_test_masks/gray/0013_label.png
#   ✓ Added molane_test_masks/gray/0191_label.png
#   ✓ Added molane_test_masks/gray/0467_label.png
#   ✓ Added molane_test_masks/gray/0131_label.png
#   ✓ Added molane_test_masks/gray/0319_label.png
#   ✓ Added molane_test_masks/gray/0406_label.png
#   ✓ Added molane_test_masks/gray/0077_label.png
#   ✓ Added molane_test_masks/gray/0125_label.png
#   ✓ Added molane_test_masks/gray/0070_label.png
#   ✓ Added molane_test_masks/gray/0188_label.png
#   ✓ Added molane_test_masks/gray/0066_label.png
#   ✓ Added molane_test_masks/gray/0486_label.png
#   ✓ Added molane_test_masks/gray/0461_label.png
#   ✓ Added molane_test_masks/gray/0228_label.png
#   ✓ Added molane_test_masks/gray/0022_label.png
#   ✓ Added molane_test_masks/gray/0073_label.png
#   ✓ Added molane_test_masks/gray/0458_label.png
#   ✓ Added molane_test_masks/gray/0031_label.png
#   ✓ Added molane_test_masks/gray/0371_label.png
#   ✓ Added molane_test_masks/gray/0374_label.png
#   ✓ Added molane_test_masks/gray/0055_label.png
#   ✓ Added molane_test_masks/gray/0496_label.png
#   ✓ Added molane_test_masks/gray/0298_label.png
#   ✓ Added molane_test_masks/gray/0351_label.png
#   ✓ Added molane_test_masks/gray/0337_label.png
#   ✓ Added molane_test_masks/gray/0079_label.png
#   ✓ Added molane_test_masks/gray/0209_label.png
#   ✓ Added molane_test_masks/gray/0288_label.png
#   ✓ Added molane_test_masks/gray/0431_label.png
#   ✓ Added molane_test_masks/gray/0301_label.png
#   ✓ Added molane_test_masks/gray/0114_label.png
#   ✓ Added molane_test_masks/gray/0457_label.png
#   ✓ Added molane_test_masks/gray/0147_label.png
#   ✓ Added molane_test_masks/gray/0352_label.png
#
# ✅ ZIP created!
#    Size: 0.01 GB
#    Path: /kaggle/working/molane_masks.zip
#
# 📥 DOWNLOAD:
#    Go to 'Output' tab and download 'molane_masks.zip'
